# %% [markdown]
# # Importing Libraries

# %%
# Importing all necessary libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
# Using data from Apple's stock.
df = pd.read_csv('../Desktop/individual_stocks_5yr/AAPL_data.csv')

# %%
df.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 69.0+ KB

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean    109.055429   109.951118   108.141589   109.066698  5.404790e+07
# std      30.549220    30.686186    30.376224    30.556812  3.346835e+07
# min      55.424200    57.085700    55.014200    55.789900  1.147592e+07
# 25%      84.647800    85.334950    84.250650    84.830650  2.969438e+07
# 50%     108.970000   110.030000   108.050000   109.010000  4.566893e+07
# 75%     127.335000   128.100000   126.290000   127.120000  6.870872e+07
# max     179.370000   180.100000   178.250000   179.260000  2.668336e+08

# %%
df.shape
# Out:
# (1259, 7)

# %% [markdown]
# # EDA

# %%
# Visualizing the opening prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Opening Price USD ($)')
plt.plot(df['open'])
plt.show()

# %%
# Visualizing the high prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('High Price USD ($)')
plt.plot(df['high'])
plt.show()

# %%
# Visualizing the low prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Low Price USD ($)')
plt.plot(df['low'])
plt.show()

# %%
# Visualizing the closing prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Closing Price USD ($)')
plt.plot(df['close'])
plt.show()

# %%
df2 = df['close']

# %%
df2.tail()
# Out:
# 1254    167.78
# 1255    160.50
# 1256    156.49
# 1257    163.03
# 1258    159.54
# Name: close, dtype: float64

# %%
df2 = pd.DataFrame(df2)

# %%
df2.tail()
# Out:
#        close
# 1254  167.78
# 1255  160.50
# 1256  156.49
# 1257  163.03
# 1258  159.54

# %%
# Prediction 100 days into the future.
future_days = 100
df2['Prediction'] = df2['close'].shift(-future_days)

# %%
df2.tail()
# Out:
#        close  Prediction
# 1254  167.78         NaN
# 1255  160.50         NaN
# 1256  156.49         NaN
# 1257  163.03         NaN
# 1258  159.54         NaN

# %%
X = np.array(df2.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[ 67.8542]
#  [ 68.5614]
#  [ 66.8428]
#  ...
#  [160.86  ]
#  [159.65  ]
#  [158.28  ]]
# C:\Users\Harsh\AppData\Local\Temp/ipykernel_4444/1853731690.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(df2.drop(['Prediction'], 1))[:-future_days]

# %%
y = np.array(df2['Prediction'])[:-future_days]
print(y)
# Out:
# [ 60.1142  59.6314  59.2928 ... 156.49   163.03   159.54  ]

# %% [markdown]
# # Linear and Decision Tree Regression

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
# Implementing Linear and Decision Tree Regression Algorithms.
tree = DecisionTreeRegressor().fit(x_train, y_train)
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = df2.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# C:\Users\Harsh\AppData\Local\Temp/ipykernel_4444/1876488320.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_future = df2.drop(['Prediction'], 1)[:-future_days]
# array([[144.53],
#        [143.68],
#        [143.79],
#        [143.65],
#        [146.58],
#        [147.51],
#        [147.06],
#        [146.53],
#        [148.96],
#        [153.01],
#        [153.99],
#        [153.26],
#        [153.95],
#        [156.1 ],
#        [155.7 ],
#        [155.47],
#        [150.25],
#        [152.54],
#        [153.06],
#        [153.99],
#        [153.8 ],
#        [153.34],
#        [153.87],
#        [153.61],
#        [153.67],
#        [152.76],
#        [153.18],
#        [155.45],
#        [153.93],
#        [154.45],
#        [155.37],
#        [154.99],
#        [148.98],
#        [145.42],
#        [146.59],
#        [145.16],
#        [144.29],
#        [142.27],
#        [146.34],
#        [145.01],
#        [145.87],
#        [145.63],
#        [146.28],
#        [145.82],
#        [143.73],
#        [145.83],
#        [143.68],
#        [144.02],
#        [143.5 ],
#        [144.09],
#        [142.73],
#        [144.18],
#        [145.06],
#        [145.53],
#        [145.74],
#        [147.77],
#        [149.04],
#        [149.56],
#        [150.08],
#        [151.02],
#        [150.34],
#        [150.27],
#        [152.09],
#        [152.74],
#        [153.46],
#        [150.56],
#        [149.5 ],
#        [148.73],
#        [158.59],
#        [157.14],
#        [155.57],
#        [156.39],
#        [158.81],
#        [160.08],
#        [161.06],
#        [155.32],
#        [157.48],
#        [159.85],
#        [161.6 ],
#        [160.95],
#        [157.86],
#        [157.5 ],
#        [157.21],
#        [159.78],
#        [159.98],
#        [159.27],
#        [159.86],
#        [161.47],
#        [162.91],
#        [163.35],
#        [164.  ],
#        [164.05],
#        [162.08],
#        [161.91],
#        [161.26],
#        [158.63],
#        [161.5 ],
#        [160.86],
#        [159.65],
#        [158.28]])

# %%
tree_prediction = tree.predict(x_future)
print(tree_prediction)
# Out:
# [159.88  169.98  158.73  156.07  153.39  151.89  150.55  153.14  154.23
#  153.28  154.48  153.81  154.48  170.57  170.57  155.3   171.7   155.9
#  156.55  154.48  156.99  159.88  160.47  159.76  155.98  172.22  156.17
#  157.1   154.48  157.41  163.05  172.23  169.04  166.89  168.11  172.5
#  174.25  174.81  176.24  175.88  174.67  173.97  171.34  169.08  171.1
#  169.08  169.98  167.305 156.07  174.97  174.09  173.07  169.48  173.97
#  171.05  151.89  169.64  169.01  169.32  169.37  172.67  171.7   172.27
#  172.22  173.97  172.67  174.54  174.35  175.01  175.01  170.57  175.01
#  171.08  178.46  174.33  172.23  173.03  175.    174.35  174.33  174.29
#  175.28  177.09  176.19  178.46  179.26  178.46  177.    177.04  177.04
#  171.11  171.51  167.96  166.97  167.43  175.01  160.5   174.33  163.03
#  159.54 ]

# %%
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [151.39368133 150.59018825 150.69416971 150.56182967 153.33151758
#  154.21063354 153.78525485 153.28425328 155.5812982  159.4097064
#  160.33608666 159.6460279  160.29827522 162.33064006 161.95252567
#  161.7351099  156.80071711 158.96542199 159.4569707  160.33608666
#  160.15648232 159.72165077 160.22265234 159.97687799 160.03359515
#  159.17338491 159.57040502 161.71620418 160.2793695  160.77091821
#  161.6405813  161.28137263 155.60020392 152.23498585 153.34097044
#  151.9892115  151.1668127  149.25733503 153.10464895 151.8474186
#  152.66036454 152.4334959  153.04793179 152.61310024 150.63745255
#  152.6225531  150.59018825 150.91158548 150.42003678 150.9777555
#  149.69216658 151.06283124 151.8946829  152.33896731 152.53747736
#  154.45640789 155.65692108 156.14846979 156.64001849 157.52858731
#  156.88579285 156.81962283 158.5400433  159.15447919 159.83508509
#  157.09375576 156.09175263 155.36388243 164.68440214 163.31373748
#  161.8296385  162.604773   164.89236506 166.09287825 167.0192585
#  161.593317   163.63513471 165.87546247 167.52971293 166.91527704
#  163.99434338 163.65404043 163.3799075  165.80929245 165.99834965
#  165.32719661 165.88491533 167.40682575 168.76803756 169.18396338
#  169.79839927 169.84566357 167.9834502  167.82275158 167.2083157
#  164.72221358 167.43518433 166.83020131 165.68640528 164.39136349]

# %%
predictions = tree_prediction 
valid = df2[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\Harsh\AppData\Local\Temp/ipykernel_4444/4118842179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(df2['close'])
plt.plot(valid[['close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()
